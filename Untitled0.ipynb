# %% [markdown]
# <a href="https://colab.research.google.com/github/nadhifaaprilia/kasir-sederhana-kelompok10/blob/fitur-input/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nadhifaaprilia/kasir-sederhana-kelompok10.git
# Out:
# Cloning into 'kasir-sederhana-kelompok10'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 24 (delta 5), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 5.94 KiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd kasir-sederhana-kelompok10
# Out:
# /content/kasir-sederhana-kelompok10

# %%
# !git switch main
# !git pull origin main
# Out:
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# From https://github.com/nadhifaaprilia/kasir-sederhana-kelompok10
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git switch -c fitur-pembayaran
# Out:
# fatal: a branch named 'fitur-pembayaran' already exists

# %%
# !git branch
# Out:
# * main

# %%
# !git switch -c fitur-pembayaran
# Out:
# Switched to a new branch 'fitur-pembayaran'

# %%
# !git branch
# Out:
# * fitur-pembayaran
#   main

# %%
# !ls
# Out:
# Kasir.py  README.md  Untitled0.ipynb

# %%
# !git branch
# Out:
# * fitur-pembayaran
#   main

# %%
total = 0 # Placeholder: Replace with actual total belanja calculation
bayar = int(input("Uang pembayaran: "))
kembalian = bayar - total

print("\n=== PEMBAYARAN ===")
print("Total belanja:", total)
print("Uang pembayaran:", bayar)
print("Kembalian:", kembalian)
# Out:
# Uang pembayaran: 20000
#
# === PEMBAYARAN ===
# Total belanja: 0
# Uang pembayaran: 20000
# Kembalian: 20000

# %%
# !git push -u origin fitur-pembayaran
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from getpass import getpass

username = input("Username GitHub: ")
token = getpass("GitHub token: ")
# Out:
# Username GitHub: ayusyadrao3126
# GitHub token: ··········

# %%
# !git remote -v
# Out:
# origin	https://github.com/nadhifaaprilia/kasir-sederhana-kelompok10.git (fetch)
# origin	https://github.com/nadhifaaprilia/kasir-sederhana-kelompok10.git (push)

# %%
# !git branch
# Out:
#   fitur-pembayaran
# * main

# %%
# !git push -u origin fitur-pembayaran
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
