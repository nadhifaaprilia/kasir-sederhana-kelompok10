# %% [markdown]
# <a href="https://colab.research.google.com/github/nadhifaaprilia/kasir-sederhana-kelompok10/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nadhifaaprilia/kasir-sederhana-kelompok10.git
# Out:
# Cloning into 'kasir-sederhana-kelompok10'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 24 (delta 5), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 5.94 KiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd kasir-sederhana-kelompok10
# Out:
# /content/kasir-sederhana-kelompok10

# %%
# !git branch
# Out:
# * main

# %%
# !git switch -c fitur-pembayaran
# Out:
# Switched to a new branch 'fitur-pembayaran'

# %%
# !git branch
# Out:
# * fitur-pembayaran
#   main

# %%
# !ls
# Out:
# Kasir.py  README.md  Untitled0.ipynb
